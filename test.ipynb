# %%
str_data = ["My name is Yusuf, My dob is 12-08-1998, I live near Banglore, I have $ 2321324 "]

# %%
from azure.ai.textanalytics import TextAnalyticsClient
from azure.identity import ClientSecretCredential

# %%
credential = ClientSecretCredential(
    tenant_id= "f22b9fef-ee8f-418e-aaf5-2289dddd4ed3", # type: ignore
    client_id= "f34e67e9-3d65-482c-bd87-66d73f095505", # type: ignore
    client_secret= "iKd8Q~jYQz3gzn2kw5wwTbhOnXouOlWAcHuPQce2 "# type: ignore
)

# %%
foundry_endpoint = "https://adiblanguageservicepoc.cognitiveservices.azure.com/language/:analyze-text?api-version=2022-05-01"

# %%
ai_client = TextAnalyticsClient(endpoint=foundry_endpoint, credential=credential)

# %%
# Get PII
pii_result = ai_client.recognize_pii_entities(documents=str_data)[0]
pii_entities = pii_result.entities
if len(pii_entities) > 0:
    print("\nPII Entities")
    for pii_entity in pii_entities:
        print('\t{} ({})'.format(pii_entity.text, pii_entity.category)) 
    print("Redacted Text:\n {}".format(pii_result.redacted_text))
# Out:
# ---------------------------------------------------------------------------
# ResourceNotFoundError                     Traceback (most recent call last)
# File c:\Users\suchitha.ishwarakhar\OneDrive - Acuvate Software Private Limited\ADIB\githubcodes\case_search\.venv\Lib\site-packages\azure\ai\textanalytics\_text_analytics_client.py:467, in TextAnalyticsClient.recognize_pii_entities(self, documents, categories_filter, disable_service_logs, domain_filter, language, model_version, show_stats, string_index_type, **kwargs)
#     464     models = self._client.models(api_version=self._api_version)
#     465     return cast(
#     466         List[Union[RecognizePiiEntitiesResult, DocumentError]],
# --> 467         self._client.analyze_text(
#     468             body=models.AnalyzeTextPiiEntitiesRecognitionInput(
#     469                 analysis_input={"documents": docs},
#     470                 parameters=models.PiiTaskParameters(
# ...
